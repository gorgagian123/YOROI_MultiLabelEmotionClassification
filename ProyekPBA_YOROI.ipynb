# %%
#Install Library 
# !pip install datasets transformers -q

from datasets import load_dataset


import pandas as pd
pd.set_option('display.max_colwidth', -1)
import numpy as np

from tqdm.notebook import tqdm
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import transformers
from sklearn import metrics, model_selection, preprocessing
from transformers import AdamW, get_linear_schedule_with_warmup
# Out:
#      |████████████████████████████████| 3.1 MB 9.5 MB/s
#      |████████████████████████████████| 596 kB 41.2 MB/s
#      |████████████████████████████████| 895 kB 70.5 MB/s
#      |████████████████████████████████| 3.3 MB 53.9 MB/s
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
#Mengambil Dataset Goemotion dan membagikan data ke dalam data train,test,dan validasi
go_emotions = load_dataset("go_emotions")

data = go_emotions.data

train = go_emotions.data["train"].to_pandas()
valid = go_emotions.data["validation"].to_pandas()
test = go_emotions.data["test"].to_pandas()
# Out:
# No config specified, defaulting to: go_emotions/simplified
# Reusing dataset go_emotions (/root/.cache/huggingface/datasets/go_emotions/simplified/0.0.0/2637cfdd4e64d30249c3ed2150fa2b9d279766bfcd6a809b9f085c61a90d776d)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Menampilkan data train
train.head(15)
# Out:
#                                                                                                                               text  ...       id
# 0   My favourite food is anything I didn't have to cook myself.                                                                     ...  eebbqej
# 1   Now if he does off himself, everyone will think hes having a laugh screwing with people instead of actually dead                ...  ed00q6i
# 2   WHY THE FUCK IS BAYLESS ISOING                                                                                                  ...  eezlygj
# 3   To make her feel threatened                                                                                                     ...  ed7ypvh
# 4   Dirty Southern Wankers                                                                                                          ...  ed0bdzj
# 5   OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe PlAyOfFs! Dumbass Broncos fans circa December 2015.                              ...  edvnz26
# 6   Yes I heard abt the f bombs! That has to be why. Thanks for your reply:) until then hubby and I will anxiously wait 😝           ...  ee3b6wu
# 7   We need more boards and to create a bit more space for [NAME]. Then we’ll be good.                                              ...  ef4qmod
# 8   Damn youtube and outrage drama is super lucrative for reddit                                                                    ...  ed8wbdn
# 9   It might be linked to the trust factor of your friend.                                                                          ...  eczgv1o
# 10  Demographics? I don’t know anybody under 35 who has cable tv.                                                                   ...  eel6g5h
# 11  Aww... she'll probably come around eventually, I'm sure she was just jealous of [NAME]... I mean, what woman wouldn't be! lol   ...  edex4ki
# 12  Hello everyone. Im from Toronto as well. Can call and visit in personal if needed.                                              ...  ef83m1s
# 13  R/sleeptrain Might be time for some sleep training. Take a look and try to feel out what's right for your family.               ...  efh7xnk
# 14  [NAME] - same fucking problem, slightly better command of the English language.                                                 ...  efdqav7
#
# [15 rows x 3 columns]

# %%
#Convert data train,test dan validasi ke one-hot representasi 
_CLASS_NAMES = [
    "admiration",
    "amusement",
    "anger",
    "annoyance",
    "approval",
    "caring",
    "confusion",
    "curiosity",
    "desire",
    "disappointment",
    "disapproval",
    "disgust",
    "embarrassment",
    "excitement",
    "fear",
    "gratitude",
    "grief",
    "joy",
    "love",
    "nervousness",
    "optimism",
    "pride",
    "realization",
    "relief",
    "remorse",
    "sadness",
    "surprise",
    "neutral",
]

mapping = dict(zip(range(len(_CLASS_NAMES)),_CLASS_NAMES))
n_labels = len(mapping)

def one_hot_labels(df):
    dict_labels = []
    for i in tqdm(range(len(df)), leave=False):
        d = dict(zip(range(n_labels), [0]*n_labels))
        labels = df.loc[i]["labels"]
        for label in labels:
            d[label] = 1
        dict_labels.append(d)
    df_labels = pd.DataFrame(dict_labels)
    return df_labels

# %%
train_oh_labels = one_hot_labels(train)
valid_oh_labels = one_hot_labels(valid)
test_oh_labels = one_hot_labels(test)
# Out:
#   0%|          | 0/43410 [00:00<?, ?it/s]
#   0%|          | 0/5426 [00:00<?, ?it/s]
#   0%|          | 0/5427 [00:00<?, ?it/s]

# %%
train_oh_labels.shape
# Out:
# (43410, 28)
